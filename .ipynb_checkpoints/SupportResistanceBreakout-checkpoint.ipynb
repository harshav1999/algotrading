# %%
import pandas as pd

# %%
df = pd.read_csv('RawDataDoNotModify/BTCUSD_Candlestick_1_Hour_BID_01.01.2020-31.08.2024.csv')
## Remove rows with no volume
df = df[df['Volume']!=0]
df = df.tail(10000)
df.reset_index(drop=True, inplace=True)

# %%
df.head(4)
# Out:
#                          Local time   Open   High    Low  Close  Volume
# 0  10.07.2023 02:00:00.000 GMT-0400  30062  30092  30022  30058  0.0769
# 1  10.07.2023 03:00:00.000 GMT-0400  30058  30111  30053  30083  0.0684
# 2  10.07.2023 04:00:00.000 GMT-0400  30079  30085  29974  30070  0.0731
# 3  10.07.2023 05:00:00.000 GMT-0400  30068  30166  30012  30116  0.0783

# %%
## Identify Support and Resistance

## 1. Indetify pivot points
def pivotid(df1, l, n1, n2): #n1 n2 before and after candle l
    if l-n1 < 0 or l+n2 >= len(df1):
        return 0
    
    pividlow=1
    pividhigh=1
    
    for i in range(l-n1, l+n2+1):
        if(df1.Low[l]>df1.Low[i]):
            pividlow=0
        if(df1.High[l]<df1.High[i]):
            pividhigh=0
    if pividlow and pividhigh:
        return 3
    elif pividlow:
        return 1
    elif pividhigh:
        return 2
    else:
        return 0
    
df['pivot'] = df.apply(lambda x: pivotid(df, x.name,10,10), axis=1)

# %%
import numpy as np
def pointpos(x):
    if x['pivot']==1:
        return x['Low']-1e-3
    elif x['pivot']==2:
        return x['High']+1e-3
    else:
        return np.nan

df['pointpos'] = df.apply(lambda row: pointpos(row), axis=1)

# %%
df[df['pointpos'].notna()]
df[df['pivot']==1]
# Out:
#                             Local time   Open   High    Low  Close  Volume  \
# 31    11.07.2023 09:00:00.000 GMT-0400  30399  30463  30283  30414  0.0630
# 61    12.07.2023 15:00:00.000 GMT-0400  30488  30489  30182  30255  0.0687
# 109   14.07.2023 15:00:00.000 GMT-0400  30089  30224  29901  30096  0.0335
# 140   15.07.2023 22:00:00.000 GMT-0400  30250  30305  30049  30236  0.0079
# 161   16.07.2023 19:00:00.000 GMT-0400  30313  30320  30131  30217  0.0170
# ...                                ...    ...    ...    ...    ...     ...
# 9771  22.08.2024 11:00:00.000 GMT-0400  60490  60802  60083  60391  0.0406
# 9825  24.08.2024 17:00:00.000 GMT-0400  64085  64145  63513  63582  0.0165
# 9898  27.08.2024 18:00:00.000 GMT-0400  60386  60386  58008  59509  0.0308
# 9916  28.08.2024 12:00:00.000 GMT-0400  58974  59182  57832  59165  0.0260
# 9964  30.08.2024 12:00:00.000 GMT-0400  58059  58560  57721  58517  0.0282
#
#       pivot   pointpos
# 31        1  30282.999
# ...

# %%
df.head()
# Out:
#                          Local time   Open   High    Low  Close  Volume  \
# 0  11.08.2024 04:00:00.000 GMT-0400  61228  61399  61137  61240  0.0141
# 1  11.08.2024 05:00:00.000 GMT-0400  61241  61793  60999  61078  0.0321
# 2  11.08.2024 06:00:00.000 GMT-0400  61078  61228  60939  61013  0.0244
# 3  11.08.2024 07:00:00.000 GMT-0400  61012  61040  60406  60650  0.0334
# 4  11.08.2024 08:00:00.000 GMT-0400  60650  60677  60221  60471  0.0353
#
#    pivot  pointpos
# 0      0       NaN
# 1      0       NaN
# 2      0       NaN
# 3      0       NaN
# 4      0       NaN

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from datetime import datetime
dfpl = df[-300:-1]
fig = go.Figure(data=[go.Candlestick(x=dfpl.index,
                open=dfpl['Open'],
                high=dfpl['High'],
                low=dfpl['Low'],
                close=dfpl['Close'],
                increasing_line_color= 'green', 
                decreasing_line_color= 'red')])

fig.add_scatter(x=dfpl.index, y=dfpl['pointpos'], mode="markers",
                marker=dict(size=5, color="MediumPurple"),
                name="pivot")
fig.update_layout(xaxis_rangeslider_visible=False)
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.update_layout(paper_bgcolor='black', plot_bgcolor='black')

fig.show()
# Out:
# <div>                            <div id="7446c205-a625-452d-854b-3d4ce085aa59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7446c205-a625-452d-854b-3d4ce085aa59")) {                    Plotly.newPlot(                        "7446c205-a625-452d-854b-3d4ce085aa59",                        [{"close":[58678,58998,58990,58941,59061,58944,59212,59430,60463,60450,60522,60616,60868,61116,60966,60910,60739,60845,60705,60510,60677,60875,59431,58796,58775,59008,59159,59472,59284,59263,59333,58980,58957,59253,59337,59286,59339,59353,59597,59689,59426,59257,59435,59338,59480,59907,59395,59496,59857,59914,60754,61576,61204,61209,61156,61135,60797,60940,60159,60535,60812,60691,60750,60980,60920,60865,61336,61329,60854,60801,60490,60391,60306,60134,60303,60274,6
# ...

# %%
# Define the function to calculate supports and resistances
def calculate_support_resistance(df, price_range, x_candles):
    # Add new columns for support and resistance based on the 'pivot' column
    df['support'] = df.apply(lambda row: row['pointpos'] if row['pivot'] == 1 else None, axis=1)
    df['resistance'] = df.apply(lambda row: row['pointpos'] if row['pivot'] == 2 else None, axis=1)
    
    # Aggregate support and resistance within the specified price range
    supports = df['support'].dropna()
    resistances = df['resistance'].dropna()
    
    def aggregate_points(points, price_range):
        averaged_points = []
        while len(points) > 0:
            current = points.iloc[0]
            close_points = points[abs(points - current) <= price_range]
            averaged_points.append(close_points.mean())
            points = points[abs(points - current) > price_range]
        return averaged_points
    
    avg_supports = aggregate_points(supports, price_range)
    avg_resistances = aggregate_points(resistances, price_range)
    
    # Find the closest aggregated support and resistance for each candle
    closest_supports = []
    closest_resistances = []
    
    for i in range(len(df)):
        past_data = df.iloc[max(0, i-x_candles):i]  # Get past x_candles
        if not past_data.empty:
            closest_supports.append(
                min(avg_supports, key=lambda s: abs(s - df.loc[i, 'Open'])) if avg_supports else None
            )
            closest_resistances.append(
                min(avg_resistances, key=lambda r: abs(r - df.loc[i, 'High'])) if avg_resistances else None
            )
        else:
            closest_supports.append(None)
            closest_resistances.append(None)
    
    df['closest_support'] = closest_supports
    df['closest_resistance'] = closest_resistances
    
    return df

# Apply the function with a price range of 500 and past 5 candles
result_df = calculate_support_resistance(df, price_range=500, x_candles=5)

# %%
class SupportResistance():
    def __init__(self, df):
        self.df = df
        self.bsp = 10
        self.asp = 10
    
    def pivotid(self, index):
        """
        1 - support
        2 - resistance
        0 - Nothing
        """
        ## edge conditions
        if index - self.bsp < 0 or index + self.asp >= len(self.df):
            return 0
        pividlow = 1
        pividhigh = 1
        for i in range(index-self.bsp, index+self.asp):
            if self.df.Low[index] > self.df.Low[i]:
                pividlow = 0
            if self.df.High[index] > self.df.High[i]:
                pividhigh = 0
        if pividlow and pividhigh:
            return 3
        elif pividlow:
            return 1
        elif pividhigh:
            return 2
        else:
            return 0
    
    # Define the function to calculate supports and resistances
    def calculate_support_resistance(self, df, price_range, x_candles):
        # Add new columns for support and resistance based on the 'pivot' column
        df['support'] = df.apply(lambda row: row['pointpos'] if row['pivot'] == 1 else None, axis=1)
        df['resistance'] = df.apply(lambda row: row['pointpos'] if row['pivot'] == 2 else None, axis=1)

        # Aggregate support and resistance within the specified price range
        supports = df['support'].dropna()
        resistances = df['resistance'].dropna()

        def aggregate_points(points, price_range):
            averaged_points = []
            while len(points) > 0:
                current = points.iloc[0]
                close_points = points[abs(points - current) <= price_range]
                averaged_points.append(close_points.mean())
                points = points[abs(points - current) > price_range]
            return averaged_points

        avg_supports = aggregate_points(supports, price_range)
        avg_resistances = aggregate_points(resistances, price_range)

        # Find the closest aggregated support and resistance for each candle
        closest_supports = []
        closest_resistances = []

        for i in range(len(df)):
            past_data = df.iloc[max(0, i-x_candles):i]  # Get past x_candles
            if not past_data.empty:
                closest_supports.append(
                    min(avg_supports, key=lambda s: abs(s - df.loc[i, 'Open'])) if avg_supports else None
                )
                closest_resistances.append(
                    min(avg_resistances, key=lambda r: abs(r - df.loc[i, 'High'])) if avg_resistances else None
                )
            else:
                closest_supports.append(None)
                closest_resistances.append(None)

        df['closest_support'] = closest_supports
        df['closest_resistance'] = closest_resistances

        return df
    
    def run(self):
